# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = "C:/Users/enhan/Downloads/Expanded_Historical_Transformer_Failures (1).csv"

# %%
df = pd.read_csv(file_path)
# Display the first few rows
print(df.head())
# Out:
#   Transformer ID                                Failure Description  \
# 0           TX-1  Sudden spike in nitrogen and methane, potentia...
# 1           TX-2  DGA analysis suggests insulation failure. High...
# 2           TX-3  CO levels rising gradually, potential core ins...
# 3           TX-4  DGA analysis suggests insulation failure. High...
# 4           TX-5  High levels of Hydrogen and Methane indicate p...
#
#                                   Maintenance Action  Hydrogen (ppm)  \
# 0  Lowered transformer load and conducted infrare...            8711
# 1  Conducted resistance and capacitance tests, no...            2660
# 2  Conducted resistance and capacitance tests, no...            4744
# 3  Lowered transformer load and conducted infrare...            8408
# 4  Lowered transformer load and conducted infrare...           12465
#
#    Methane (ppm)  CO (ppm)  CO2 (ppm)  Ethylene (ppm)  Ethane (ppm)  \
# 0            732       392       2208             844           222
# 1           4971       184       3184             719           235
# 2           2568       361       2453             258           163
# 3           7714       331       4279             728           188
# 4           8483       170       2321             831           316
#
#    Acetylene (ppm)  DBDS (ppm)  Power Factor  Interfacial Voltage (kV)  \
# 0              545          95          1.10                        41
# 1             2243          79          2.12                        56
# 2             1724          82          4.59                        52
# 3              588         100          3.90                        38
# 4             2255           8          3.12                        60
#
#    Dielectric Rigidity (kV)  Water Content (ppm)  Health Index
# 0                        43                   17          86.0
# 1                        41                   39          97.1
# 2                        60                    3          76.6
# 3                        44                   45          78.1
# 4                        48                    5          85.2

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# Transformer ID              0
# Failure Description         0
# Maintenance Action          0
# Hydrogen (ppm)              0
# Methane (ppm)               0
# CO (ppm)                    0
# CO2 (ppm)                   0
# Ethylene (ppm)              0
# Ethane (ppm)                0
# Acetylene (ppm)             0
# DBDS (ppm)                  0
# Power Factor                0
# Interfacial Voltage (kV)    0
# Dielectric Rigidity (kV)    0
# Water Content (ppm)         0
# Health Index                0
# dtype: int64

# %%
file_path_health = "C:/Users/enhan/Downloads/archive (1)/Health index1.csv"
df_healthID = pd.read_csv(file_path_health)

# %%
# Check for missing values
print(df_healthID.isnull().sum())
# Out:
# Hydrogen               0
# Oxigen                 0
# Nitrogen               0
# Methane                0
# CO                     0
# CO2                    0
# Ethylene               0
# Ethane                 0
# Acethylene             0
# DBDS                   0
# Power factor           0
# Interfacial V          0
# Dielectric rigidity    0
# Water content          0
# Health index           0
# Life expectation       0
# dtype: int64

# %%
# Display the first few rows
print(df_healthID.head())
# Out:
#    Hydrogen  Oxigen  Nitrogen  Methane   CO   CO2  Ethylene  Ethane  \
# 0      2845    5860     27842     7406   32  1344     16684    5467
# 1     12886      61     25041      877   83   864         4     305
# 2      2820   16400     56300      144  257  1080       206      11
# 3      1099      70     37520      545  184  1402         6     230
# 4      3210    3570     47900      160  360  2130         4      43
#
#    Acethylene  DBDS  Power factor  Interfacial V  Dielectric rigidity  \
# 0           7  19.0          1.00             45                   55
# 1           0  45.0          1.00             45                   55
# 2        2190   1.0          1.00             39                   52
# 3           0  87.0          4.58             33                   49
# 4           4   1.0          0.77             44                   55
#
#    Water content  Health index  Life expectation
# 0              0          95.2              19.0
# 1              0          85.5              19.0
# 2             11          85.3              19.0
# 3              5          85.3               6.0
# 4              3          85.2               6.0

# %% [markdown]
#                                                                         EDA

# %%
# Print column names for both datasets
print("Columns in df_healthID (Health Index Dataset):")
print(df_healthID.columns)

print("\nColumns in df (Transformer Failures Dataset):")
print(df.columns)
# Out:
# Columns in df_healthID (Health Index Dataset):
# Index(['Hydrogen', 'Oxigen', 'Nitrogen', 'Methane', 'CO', 'CO2', 'Ethylene',
#        'Ethane', 'Acethylene', 'DBDS', 'Power factor', 'Interfacial V',
#        'Dielectric rigidity', 'Water content', 'Health index',
#        'Life expectation'],
#       dtype='object')
#
# Columns in df (Transformer Failures Dataset):
# Index(['Transformer ID', 'Failure Description', 'Maintenance Action',
#        'Hydrogen (ppm)', 'Methane (ppm)', 'CO (ppm)', 'CO2 (ppm)',
#        'Ethylene (ppm)', 'Ethane (ppm)', 'Acetylene (ppm)', 'DBDS (ppm)',
#        'Power Factor', 'Interfacial Voltage (kV)', 'Dielectric Rigidity (kV)',
#        'Water Content (ppm)', 'Health Index'],
#       dtype='object')

# %%
# Ensure df_healthID has Transformer IDs
df_healthID["Transformer ID"] = [f"TX-{i}" for i in range(1, len(df_healthID) + 1)]

# Display updated df_healthID
print(df_healthID.head())
# Out:
#    Hydrogen  Oxigen  Nitrogen  Methane   CO   CO2  Ethylene  Ethane  \
# 0      2845    5860     27842     7406   32  1344     16684    5467
# 1     12886      61     25041      877   83   864         4     305
# 2      2820   16400     56300      144  257  1080       206      11
# 3      1099      70     37520      545  184  1402         6     230
# 4      3210    3570     47900      160  360  2130         4      43
#
#    Acethylene  DBDS  Power factor  Interfacial V  Dielectric rigidity  \
# 0           7  19.0          1.00             45                   55
# 1           0  45.0          1.00             45                   55
# 2        2190   1.0          1.00             39                   52
# 3           0  87.0          4.58             33                   49
# 4           4   1.0          0.77             44                   55
#
#    Water content  Health index  Life expectation Transformer ID
# 0              0          95.2              19.0           TX-1
# 1              0          85.5              19.0           TX-2
# 2             11          85.3              19.0           TX-3
# 3              5          85.3               6.0           TX-4
# 4              3          85.2               6.0           TX-5

# %%
print("\nColumns in df (Transformer Failures Dataset):")
print(df.columns)

print("\nColumns in df_healthID (Health Index Dataset):")
print(df_healthID.columns)
# Out:
# Columns in df (Transformer Failures Dataset):
# Index(['Transformer ID', 'Failure Description', 'Maintenance Action',
#        'Hydrogen (ppm)', 'Methane (ppm)', 'CO (ppm)', 'CO2 (ppm)',
#        'Ethylene (ppm)', 'Ethane (ppm)', 'Acetylene (ppm)', 'DBDS (ppm)',
#        'Power Factor', 'Interfacial Voltage (kV)', 'Dielectric Rigidity (kV)',
#        'Water Content (ppm)', 'Health Index'],
#       dtype='object')
#
# Columns in df_healthID (Health Index Dataset):
# Index(['Hydrogen', 'Oxigen', 'Nitrogen', 'Methane', 'CO', 'CO2', 'Ethylene',
#        'Ethane', 'Acethylene', 'DBDS', 'Power factor', 'Interfacial V',
#        'Dielectric rigidity', 'Water content', 'Health index',
#        'Life expectation', 'Transformer ID'],
#       dtype='object')

# %%
# Rename columns in df_healthID to match df
df_healthID.rename(columns={
    "Oxigen": "Oxygen",  # Fix spelling
    "Acethylene": "Acetylene (ppm)",  # Match df naming
    "Power factor": "Power Factor",
    "Interfacial V": "Interfacial Voltage (kV)",
    "Dielectric rigidity": "Dielectric Rigidity (kV)",
    "Water content": "Water Content (ppm)",
    "Health index": "Health Index"  # Match df naming
}, inplace=True)

# Display updated column names
print("\nUpdated Columns in df_healthID:")
print(df_healthID.columns)
# Out:
# Updated Columns in df_healthID:
# Index(['Hydrogen', 'Oxygen', 'Nitrogen', 'Methane', 'CO', 'CO2', 'Ethylene',
#        'Ethane', 'Acetylene (ppm)', 'DBDS', 'Power Factor',
#        'Interfacial Voltage (kV)', 'Dielectric Rigidity (kV)',
#        'Water Content (ppm)', 'Health Index', 'Life expectation',
#        'Transformer ID'],
#       dtype='object')

# %%
# Merge datasets on Transformer ID
df_merged = pd.merge(df, df_healthID, on="Transformer ID", how="inner")

# Display first few rows of the merged dataset
print("\nMerged Dataset:")
print(df_merged.head())
# Out:
# Merged Dataset:
#   Transformer ID                                Failure Description  \
# 0           TX-1  Sudden spike in nitrogen and methane, potentia...
# 1           TX-2  DGA analysis suggests insulation failure. High...
# 2           TX-3  CO levels rising gradually, potential core ins...
# 3           TX-4  DGA analysis suggests insulation failure. High...
# 4           TX-5  High levels of Hydrogen and Methane indicate p...
#
#                                   Maintenance Action  Hydrogen (ppm)  \
# 0  Lowered transformer load and conducted infrare...            8711
# 1  Conducted resistance and capacitance tests, no...            2660
# 2  Conducted resistance and capacitance tests, no...            4744
# 3  Lowered transformer load and conducted infrare...            8408
# 4  Lowered transformer load and conducted infrare...           12465
#
#    Methane (ppm)  CO (ppm)  CO2 (ppm)  Ethylene (ppm)  Ethane (ppm)  \
# 0            732       392       2208             844           222
# 1           4971       184       3184             719           235
# 2           2568       361       2453             258           163
# 3           7714       331       4279             728           188
# 4           8483       170       2321             831           316
#
#    Acetylene (ppm)_x  ...  Ethylene  Ethane  Acetylene (ppm)_y  DBDS  \
# 0                545  ...     16684    5467                  7  19.0
# 1               2243  ...         4     305                  0  45.0
# 2               1724  ...       206      11               2190   1.0
# 3                588  ...         6     230                  0  87.0
# 4               2255  ...         4      43                  4   1.0
#
#    Power Factor_y  Interfacial Voltage (kV)_y  Dielectric Rigidity (kV)_y  \
# 0            1.00                          45                          55
# 1            1.00                          45                          55
# 2            1.00                          39                          52
# 3            4.58                          33                          49
# 4            0.77                          44                          55
#
#    Water Content (ppm)_y  Health Index_y  Life expectation
# 0                      0            95.2              19.0
# 1                      0            85.5              19.0
# 2                     11            85.3              19.0
# 3                      5            85.3               6.0
# 4                      3            85.2               6.0
#
# [5 rows x 32 columns]

# %%
print("\nColumns in df_merged:")
print(df_merged.columns)
# Out:
# Columns in df_merged:
# Index(['Transformer ID', 'Failure Description', 'Maintenance Action',
#        'Hydrogen (ppm)', 'Methane (ppm)', 'CO (ppm)', 'CO2 (ppm)',
#        'Ethylene (ppm)', 'Ethane (ppm)', 'Acetylene (ppm)_x', 'DBDS (ppm)',
#        'Power Factor_x', 'Interfacial Voltage (kV)_x',
#        'Dielectric Rigidity (kV)_x', 'Water Content (ppm)_x', 'Health Index_x',
#        'Hydrogen', 'Oxygen', 'Nitrogen', 'Methane', 'CO', 'CO2', 'Ethylene',
#        'Ethane', 'Acetylene (ppm)_y', 'DBDS', 'Power Factor_y',
#        'Interfacial Voltage (kV)_y', 'Dielectric Rigidity (kV)_y',
#        'Water Content (ppm)_y', 'Health Index_y', 'Life expectation'],
#       dtype='object')

# %%
# Drop duplicate sensor columns and keep only one Health Index column
df_merged = df_merged.drop(columns=["Health Index_x", "Acetylene (ppm)_x", "Power Factor_x",
                                    "Interfacial Voltage (kV)_x", "Dielectric Rigidity (kV)_x",
                                    "Water Content (ppm)_x"])

# Rename the correct Health Index column
df_merged.rename(columns={"Health Index_y": "Health Index",
                          "Acetylene (ppm)_y": "Acetylene (ppm)",
                          "Power Factor_y": "Power Factor",
                          "Interfacial Voltage (kV)_y": "Interfacial Voltage (kV)",
                          "Dielectric Rigidity (kV)_y": "Dielectric Rigidity (kV)",
                          "Water Content (ppm)_y": "Water Content (ppm)"}, inplace=True)

# Display cleaned column names
print("\nUpdated Columns in df_merged:")
print(df_merged.columns)
# Out:
# Updated Columns in df_merged:
# Index(['Transformer ID', 'Failure Description', 'Maintenance Action',
#        'Hydrogen (ppm)', 'Methane (ppm)', 'CO (ppm)', 'CO2 (ppm)',
#        'Ethylene (ppm)', 'Ethane (ppm)', 'DBDS (ppm)', 'Hydrogen', 'Oxygen',
#        'Nitrogen', 'Methane', 'CO', 'CO2', 'Ethylene', 'Ethane',
#        'Acetylene (ppm)', 'DBDS', 'Power Factor', 'Interfacial Voltage (kV)',
#        'Dielectric Rigidity (kV)', 'Water Content (ppm)', 'Health Index',
#        'Life expectation'],
#       dtype='object')

# %%
def classify_health_index(hi):
    if hi > 90:
        return "Healthy"
    elif 80 < hi <= 90:
        return "Warning"
    else:
        return "Critical"

# Apply classification to df_merged
df_merged["Health Risk Level"] = df_merged["Health Index"].apply(classify_health_index)

# Display first few rows of updated dataset
print("\nUpdated Dataset with Health Risk Levels:")
print(df_merged.head())
# Out:
# Updated Dataset with Health Risk Levels:
#   Transformer ID                                Failure Description  \
# 0           TX-1  Sudden spike in nitrogen and methane, potentia...
# 1           TX-2  DGA analysis suggests insulation failure. High...
# 2           TX-3  CO levels rising gradually, potential core ins...
# 3           TX-4  DGA analysis suggests insulation failure. High...
# 4           TX-5  High levels of Hydrogen and Methane indicate p...
#
#                                   Maintenance Action  Hydrogen (ppm)  \
# 0  Lowered transformer load and conducted infrare...            8711
# 1  Conducted resistance and capacitance tests, no...            2660
# 2  Conducted resistance and capacitance tests, no...            4744
# 3  Lowered transformer load and conducted infrare...            8408
# 4  Lowered transformer load and conducted infrare...           12465
#
#    Methane (ppm)  CO (ppm)  CO2 (ppm)  Ethylene (ppm)  Ethane (ppm)  \
# 0            732       392       2208             844           222
# 1           4971       184       3184             719           235
# 2           2568       361       2453             258           163
# 3           7714       331       4279             728           188
# 4           8483       170       2321             831           316
#
#    DBDS (ppm)  ...  Ethane  Acetylene (ppm)  DBDS  Power Factor  \
# 0          95  ...    5467                7  19.0          1.00
# 1          79  ...     305                0  45.0          1.00
# 2          82  ...      11             2190   1.0          1.00
# 3         100  ...     230                0  87.0          4.58
# 4           8  ...      43                4   1.0          0.77
#
#    Interfacial Voltage (kV)  Dielectric Rigidity (kV)  Water Content (ppm)  \
# 0                        45                        55                    0
# 1                        45                        55                    0
# 2                        39                        52                   11
# 3                        33                        49                    5
# 4                        44                        55                    3
#
#    Health Index  Life expectation  Health Risk Level
# 0          95.2              19.0            Healthy
# 1          85.5              19.0            Warning
# 2          85.3              19.0            Warning
# 3          85.3               6.0            Warning
# 4          85.2               6.0            Warning
#
# [5 rows x 27 columns]

# %%
# Check data types of df_merged columns
df_merged.dtypes
# Out:
# Transformer ID               object
# Failure Description          object
# Maintenance Action           object
# Hydrogen (ppm)                int64
# Methane (ppm)                 int64
# CO (ppm)                      int64
# CO2 (ppm)                     int64
# Ethylene (ppm)                int64
# Ethane (ppm)                  int64
# DBDS (ppm)                    int64
# Hydrogen                      int64
# Oxygen                        int64
# Nitrogen                      int64
# Methane                       int64
# CO                            int64
# CO2                           int64
# Ethylene                      int64
# Ethane                        int64
# Acetylene (ppm)               int64
# DBDS                        float64
# Power Factor                float64
# Interfacial Voltage (kV)      int64
# Dielectric Rigidity (kV)      int64
# Water Content (ppm)           int64
# Health Index                float64
# Life expectation            float64
# Health Risk Level            object
# dtype: object

# %%
# Convert Health Risk Level to categorical
df_merged["Health Risk Level"] = df_merged["Health Risk Level"].astype("category")

# Verify changes
print(df_merged.dtypes["Health Risk Level"])
# Out:
# category

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Exclude non-numeric columns
numeric_df = df_merged.select_dtypes(include=["number"])

# Generate Correlation Heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap of Sensor Readings")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

 

# Display summary statistics
print("\nSummary Statistics:")
print(df_merged.describe())

# Plot distribution of Health Index
plt.figure(figsize=(8, 5))
sns.histplot(df_merged["Health Index"], bins=20, kde=True, color="blue")
plt.title("Distribution of Health Index")
plt.xlabel("Health Index")
plt.ylabel("Frequency")
plt.show()

# Box plot for detecting outliers in key sensor readings
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_merged[["Hydrogen", "Methane", "CO", "CO2", "Ethylene", "Ethane", "Acetylene (ppm)"]])
plt.title("Boxplot of Sensor Readings (Outlier Detection)")
plt.xticks(rotation=45)
plt.show()

# Correlation Heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(df_merged.corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap of Sensor Readings")
plt.show()
# Out:
# Summary Statistics:
#        Hydrogen (ppm)  Methane (ppm)    CO (ppm)    CO2 (ppm)  Ethylene (ppm)  \
# count      100.000000     100.000000  100.000000   100.000000      100.000000
# mean      7767.950000    4631.630000  234.290000  2756.680000      476.270000
# std       4281.579253    2969.852888  138.961392  1359.327068      287.555453
# min        269.000000     225.000000   10.000000   514.000000       13.000000
# 25%       4528.250000    2345.000000  108.000000  1508.250000      220.500000
# 50%       8112.500000    4570.500000  229.500000  2543.500000      513.500000
# 75%      11578.250000    7004.750000  349.750000  4038.750000      727.250000
# max      14863.000000    9960.000000  495.000000  4999.000000      999.000000
#
#        Ethane (ppm)  DBDS (ppm)      Hydrogen         Oxygen     Nitrogen  \
# count    100.000000  100.000000    100.000000     100.000000    100.00000
# mean     254.020000   47.830000   1802.320000   10669.610000  50872.76000
# std      136.587781   30.992034   4054.930925   25745.534413  14162.57655
# min       10.000000    0.000000      0.000000      57.000000  16464.00000
# 25%      152.750000   21.000000      4.000000     589.250000  43395.00000
# 50%      238.500000   43.500000     30.000000    3345.500000  50550.00000
# 75%      382.250000   75.250000    631.750000   16625.000000  58800.00000
# max      491.000000  100.000000  23349.000000  249900.000000  81300.00000
#
#        ...      Ethylene       Ethane  Acetylene (ppm)        DBDS  \
# count  ...    100.000000   100.000000       100.000000  100.000000
# mean   ...    751.470000   206.100000       429.910000   67.762000
# std    ...   2803.100839   693.148774      1349.089413   75.055212
# min    ...      0.000000     0.000000         0.000000    0.000000
# 25%    ...      4.000000     1.500000         0.000000    0.000000
# 50%    ...      9.000000    21.000000         0.000000   18.000000
# 75%    ...     66.500000    50.000000         2.000000  144.000000
# max    ...  16684.000000  5467.000000      9740.000000  227.000000
#
#        Power Factor  Interfacial Voltage (kV)  Dielectric Rigidity (kV)  \
# count    100.000000                100.000000                100.000000
# mean       3.450500                 41.170000                 52.550000
# std       12.649609                  4.494789                  7.444576
# min        0.080000                 24.000000                 28.000000
# 25%        0.320000                 40.000000                 50.000000
# 50%        0.875000                 42.000000                 54.000000
# 75%        1.000000                 44.000000                 55.250000
# max       73.200000                 52.000000                 75.000000
#
#        Water Content (ppm)  Health Index  Life expectation
# count             100.0000    100.000000        100.000000
# mean               10.1700     54.209000         16.489000
# std                12.0605     10.032614          9.064248
# min                 0.0000     48.200000          6.000000
# 25%                 4.0000     48.200000          6.500000
# 50%                 6.0000     50.150000         17.900000
# 75%                11.2500     57.550000         19.000000
# max                77.0000     95.200000         31.100000
#
# [8 rows x 23 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 28
#      26 # Correlation Heatmap
#      27 plt.figure(figsize=(12, 8))
# ---> 28 sns.heatmap(df_merged.corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
#      29 plt.title("Correlation Heatmap of Sensor Readings")
#      30 plt.show()
#
# File c:\Users\enhan\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\enhan\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File c:\Users\enhan\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File c:\Users\enhan\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'TX-1'

# %%
# !pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\enhan\appdata\local\programs\python\python310\lib\site-packages (0.13.0)
# Requirement already satisfied: numpy<3,>=1.24.3 in c:\users\enhan\appdata\local\programs\python\python310\lib\site-packages (from imbalanced-learn) (1.26.4)
# Requirement already satisfied: scipy<2,>=1.10.1 in c:\users\enhan\appdata\local\programs\python\python310\lib\site-packages (from imbalanced-learn) (1.15.2)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in c:\users\enhan\appdata\local\programs\python\python310\lib\site-packages (from imbalanced-learn) (1.6.1)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in c:\users\enhan\appdata\local\programs\python\python310\lib\site-packages (from imbalanced-learn) (0.1.3)
# Requirement already satisfied: joblib<2,>=1.1.1 in c:\users\enhan\appdata\local\programs\python\python310\lib\site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\enhan\appdata\local\programs\python\python310\lib\site-packages (from imbalanced-learn) (3.5.0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Check class distribution of Health Risk Level
plt.figure(figsize=(8, 5))
sns.countplot(x=df_merged["Health Risk Level"], palette="viridis")
plt.title("Distribution of Health Risk Levels")
plt.xlabel("Health Risk Level")
plt.ylabel("Count")
plt.show()

# Display value counts
df_merged["Health Risk Level"].value_counts(normalize=True)
# Out:
# C:\Users\enhan\AppData\Local\Temp\ipykernel_47256\2801767531.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df_merged["Health Risk Level"], palette="viridis")
# Health Risk Level
# Critical    0.95
# Warning     0.04
# Healthy     0.01
# Name: proportion, dtype: float64

# %%
import imblearn
print("imbalanced-learn version:", imblearn.__version__)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 import imblearn
#       2 print("imbalanced-learn version:", imblearn.__version__)
#
# File c:\Users\enhan\AppData\Local\Programs\Python\Python310\lib\site-packages\imblearn\__init__.py:52
#      48     sys.stderr.write("Partial import of imblearn during the build process.\n")
#      49     # We are not importing the rest of scikit-learn during the build
#      50     # process, as it may not be compiled yet
#      51 else:
# ---> 52     from . import (
#      53         combine,
#      54         ensemble,
#      55         exceptions,
#      56         metrics,
#      57         over_sampling,
#      58         pipeline,
#      59         tensorflow,
#      60         under_sampling,
#      61         utils,
#      62     )
#      63     from ._version import __version__
#      64     from .base import FunctionSampler
#
# File c:\Users\enhan\AppData\Local\Programs\Python\Python310\lib\site-packages\imblearn\combine\__init__.py:5
#       1 """The :mod:`imblearn.combine` provides methods which combine
#       2 over-sampling and under-sampling.
#       3 """
# ----> 5 from ._smote_enn import SMOTEENN
#       6 from ._smote_tomek import SMOTETomek
#       8 __all__ = ["SMOTEENN", "SMOTETomek"]
#
# File c:\Users\enhan\AppData\Local\Programs\Python\Python310\lib\site-packages\imblearn\combine\_smote_enn.py:12
#       9 from sklearn.base import clone
#      10 from sklearn.utils import check_X_y
# ---> 12 from ..base import BaseSampler
#      13 from ..over_sampling import SMOTE
#      14 from ..over_sampling.base import BaseOverSampler
#
# File c:\Users\enhan\AppData\Local\Programs\Python\Python310\lib\site-packages\imblearn\base.py:15
#      12 from sklearn.utils._metadata_requests import METHODS
#      13 from sklearn.utils.multiclass import check_classification_targets
# ---> 15 from .utils import check_sampling_strategy, check_target_type
#      16 from .utils._sklearn_compat import _fit_context, get_tags, validate_data
#      17 from .utils._validation import ArraysTransformer
#
# File c:\Users\enhan\AppData\Local\Programs\Python\Python310\lib\site-packages\imblearn\utils\__init__.py:6
#       1 """
#       2 The :mod:`imblearn.utils` module includes various utilities.
#       3 """
#       5 from ._docstring import Substitution
# ----> 6 from ._validation import (
#       7     check_neighbors_object,
#       8     check_sampling_strategy,
#       9     check_target_type,
#      10 )
#      12 __all__ = [
#      13     "check_neighbors_object",
#      14     "check_sampling_strategy",
#      15     "check_target_type",
#      16     "Substitution",
#      17 ]
#
# File c:\Users\enhan\AppData\Local\Programs\Python\Python310\lib\site-packages\imblearn\utils\_validation.py:20
#      17 from sklearn.utils.multiclass import type_of_target
#      18 from sklearn.utils.validation import _num_samples
# ---> 20 from ..utils._sklearn_compat import _is_pandas_df, check_array
#      22 SAMPLING_KIND = (
#      23     "over-sampling",
#      24     "under-sampling",
#    (...)
#      27     "bypass",
#      28 )
#      29 TARGET_KIND = ("binary", "multiclass", "multilabel-indicator")
#
# File c:\Users\enhan\AppData\Local\Programs\Python\Python310\lib\site-packages\imblearn\utils\_sklearn_compat.py:815
#     811 @dataclass(**_dataclass_args())
#     812 class Tags(Tags):
#     813     sampler_tags: SamplerTags | None = None
# --> 815 from sklearn.utils._test_common.instance_generator import (
#     816     _construct_instances,  # noqa: F401
#     817 )
#     818 from sklearn.utils.estimator_checks import (
#     819     check_estimator,  # noqa: F401
#     820     parametrize_with_checks,  # noqa: F401
#     821 )
#     822 from sklearn.utils.multiclass import type_of_target  # noqa: F401
#
# File c:\Users\enhan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_test_common\instance_generator.py:179
#     177 from sklearn.utils import all_estimators
#     178 from sklearn.utils._tags import get_tags
# --> 179 from sklearn.utils._testing import SkipTest
#     181 CROSS_DECOMPOSITION = ["PLSCanonical", "PLSRegression", "CCA", "PLSSVD"]
#     183 # The following dictionary is to indicate constructor arguments suitable for the test
#     184 # suite, which uses very small datasets, and is intended to run rather quickly.
#
# File c:\Users\enhan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_testing.py:32
#      30 import numpy as np
#      31 import scipy as sp
# ---> 32 from numpy.testing import assert_allclose as np_assert_allclose
#      33 from numpy.testing import (
#      34     assert_almost_equal,
#      35     assert_array_almost_equal,
#      36     assert_array_equal,
#      37     assert_array_less,
#      38 )
#      40 import sklearn
#
# File c:\Users\enhan\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\testing\__init__.py:11
#       8 from unittest import TestCase
#      10 from . import _private
# ---> 11 from ._private.utils import *
#      12 from ._private.utils import (_assert_valid_refcount, _gen_alignment_data)
#      13 from ._private import extbuild
#
# File c:\Users\enhan\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\testing\_private\utils.py:26
#      23 import importlib.metadata
#      25 import numpy as np
# ---> 26 from numpy._core import (
#      27      intp, float32, empty, arange, array_repr, ndarray, isnat, array)
#      28 from numpy import isfinite, isnan, isinf
#      29 import numpy.linalg._umath_linalg
#
# ImportError: cannot import name 'intp' from 'numpy._core' (c:\Users\enhan\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\_core\__init__.py)

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter
from sklearn.model_selection import train_test_split

# Extract features and target variable
features = ["Hydrogen", "Oxygen", "Nitrogen", "Methane", "CO", "CO2", "Ethylene",
            "Ethane", "Acetylene (ppm)", "DBDS", "Power Factor",
            "Interfacial Voltage (kV)", "Dielectric Rigidity (kV)", "Water Content (ppm)"]

X = df_merged[features]
y = df_merged["Health Risk Level"]

# Encode target variable (convert categories to numbers)
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Apply SMOTE to balance the dataset
smote = SMOTE(sampling_strategy="auto", random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y_encoded)

# Convert back to dataframe for verification
df_resampled = pd.DataFrame(X_resampled, columns=features)
df_resampled["Health Risk Level"] = label_encoder.inverse_transform(y_resampled)

# Check class distribution after balancing
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))
sns.countplot(x=df_resampled["Health Risk Level"], palette="viridis")
plt.title("Balanced Distribution of Health Risk Levels (After SMOTE)")
plt.xlabel("Health Risk Level")
plt.ylabel("Count")
plt.show()

# Display new class distribution
print(df_resampled["Health Risk Level"].value_counts(normalize=True))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 from imblearn.over_sampling import SMOTE
#       2 from collections import Counter
#       3 from sklearn.model_selection import train_test_split
#
# File c:\Users\enhan\AppData\Local\Programs\Python\Python310\lib\site-packages\imblearn\__init__.py:52
#      48     sys.stderr.write("Partial import of imblearn during the build process.\n")
#      49     # We are not importing the rest of scikit-learn during the build
#      50     # process, as it may not be compiled yet
#      51 else:
# ---> 52     from . import (
#      53         combine,
#      54         ensemble,
#      55         exceptions,
#      56         metrics,
#      57         over_sampling,
#      58         pipeline,
#      59         tensorflow,
#      60         under_sampling,
#      61         utils,
#      62     )
#      63     from ._version import __version__
#      64     from .base import FunctionSampler
#
# File c:\Users\enhan\AppData\Local\Programs\Python\Python310\lib\site-packages\imblearn\combine\__init__.py:5
#       1 """The :mod:`imblearn.combine` provides methods which combine
#       2 over-sampling and under-sampling.
#       3 """
# ----> 5 from ._smote_enn import SMOTEENN
#       6 from ._smote_tomek import SMOTETomek
#       8 __all__ = ["SMOTEENN", "SMOTETomek"]
#
# File c:\Users\enhan\AppData\Local\Programs\Python\Python310\lib\site-packages\imblearn\combine\_smote_enn.py:12
#       9 from sklearn.base import clone
#      10 from sklearn.utils import check_X_y
# ---> 12 from ..base import BaseSampler
#      13 from ..over_sampling import SMOTE
#      14 from ..over_sampling.base import BaseOverSampler
#
# File c:\Users\enhan\AppData\Local\Programs\Python\Python310\lib\site-packages\imblearn\base.py:15
#      12 from sklearn.utils._metadata_requests import METHODS
#      13 from sklearn.utils.multiclass import check_classification_targets
# ---> 15 from .utils import check_sampling_strategy, check_target_type
#      16 from .utils._sklearn_compat import _fit_context, get_tags, validate_data
#      17 from .utils._validation import ArraysTransformer
#
# File c:\Users\enhan\AppData\Local\Programs\Python\Python310\lib\site-packages\imblearn\utils\__init__.py:6
#       1 """
#       2 The :mod:`imblearn.utils` module includes various utilities.
#       3 """
#       5 from ._docstring import Substitution
# ----> 6 from ._validation import (
#       7     check_neighbors_object,
#       8     check_sampling_strategy,
#       9     check_target_type,
#      10 )
#      12 __all__ = [
#      13     "check_neighbors_object",
#      14     "check_sampling_strategy",
#      15     "check_target_type",
#      16     "Substitution",
#      17 ]
#
# File c:\Users\enhan\AppData\Local\Programs\Python\Python310\lib\site-packages\imblearn\utils\_validation.py:20
#      17 from sklearn.utils.multiclass import type_of_target
#      18 from sklearn.utils.validation import _num_samples
# ---> 20 from ..utils._sklearn_compat import _is_pandas_df, check_array
#      22 SAMPLING_KIND = (
#      23     "over-sampling",
#      24     "under-sampling",
#    (...)
#      27     "bypass",
#      28 )
#      29 TARGET_KIND = ("binary", "multiclass", "multilabel-indicator")
#
# File c:\Users\enhan\AppData\Local\Programs\Python\Python310\lib\site-packages\imblearn\utils\_sklearn_compat.py:815
#     811 @dataclass(**_dataclass_args())
#     812 class Tags(Tags):
#     813     sampler_tags: SamplerTags | None = None
# --> 815 from sklearn.utils._test_common.instance_generator import (
#     816     _construct_instances,  # noqa: F401
#     817 )
#     818 from sklearn.utils.estimator_checks import (
#     819     check_estimator,  # noqa: F401
#     820     parametrize_with_checks,  # noqa: F401
#     821 )
#     822 from sklearn.utils.multiclass import type_of_target  # noqa: F401
#
# File c:\Users\enhan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_test_common\instance_generator.py:179
#     177 from sklearn.utils import all_estimators
#     178 from sklearn.utils._tags import get_tags
# --> 179 from sklearn.utils._testing import SkipTest
#     181 CROSS_DECOMPOSITION = ["PLSCanonical", "PLSRegression", "CCA", "PLSSVD"]
#     183 # The following dictionary is to indicate constructor arguments suitable for the test
#     184 # suite, which uses very small datasets, and is intended to run rather quickly.
#
# File c:\Users\enhan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_testing.py:32
#      30 import numpy as np
#      31 import scipy as sp
# ---> 32 from numpy.testing import assert_allclose as np_assert_allclose
#      33 from numpy.testing import (
#      34     assert_almost_equal,
#      35     assert_array_almost_equal,
#      36     assert_array_equal,
#      37     assert_array_less,
#      38 )
#      40 import sklearn
#
# File c:\Users\enhan\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\testing\__init__.py:11
#       8 from unittest import TestCase
#      10 from . import _private
# ---> 11 from ._private.utils import *
#      12 from ._private.utils import (_assert_valid_refcount, _gen_alignment_data)
#      13 from ._private import extbuild
#
# File c:\Users\enhan\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\testing\_private\utils.py:26
#      23 import importlib.metadata
#      25 import numpy as np
# ---> 26 from numpy._core import (
#      27      intp, float32, empty, arange, array_repr, ndarray, isnat, array)
#      28 from numpy import isfinite, isnan, isinf
#      29 import numpy.linalg._umath_linalg
#
# ImportError: cannot import name 'intp' from 'numpy._core' (c:\Users\enhan\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\_core\__init__.py)

# %% [markdown]
# Class Balance Analysis: Health Risk Level Distribution
# The distribution of Health Risk Levels is highly imbalanced, with the majority of transformers classified as "Critical", while "Healthy" and "Warning" cases are severely underrepresented.
#
# Key Findings:
# Critical Condition Dominates → The dataset is mostly composed of transformers in critical condition, which could lead to a model that is biased toward predicting failures.
# Severe Class Imbalance → There are very few Healthy and Warning examples, which may result in poor predictive accuracy for these categories.
# Potential Model Issues:
# The model might overfit to predicting "Critical" since it sees this class the most.
# The Healthy and Warning classes might be underpredicted or ignored by the model.

# %% [markdown]
# Exploratory Data Analysis (EDA) Results
# 1. Distribution of Health Index
# The Health Index distribution is skewed toward lower values, indicating that a significant portion of transformers have poor health.
# Most transformers fall in the 50-60 range, suggesting that the dataset primarily consists of transformers in warning or critical condition.
# Very few transformers have a Health Index above 80, which means there are limited examples of healthy transformers.
# 2. Boxplot Analysis – Detecting Outliers in Sensor Readings
# The boxplot of Hydrogen, Methane, CO, CO2, Ethylene, Ethane, and Acetylene (ppm) reveals a significant number of outliers in various gas concentrations.
# Hydrogen and CO2 levels show extreme values (some exceeding 25,000 ppm), which may indicate critical transformer failures or sensor anomalies.
# Other gases, such as Methane and Ethylene, have some outliers but remain within a more reasonable range.
# The presence of many outliers suggests that either:
# These are genuine failure cases (severe transformer degradation).
# There are possible sensor measurement errors or inconsistencies.
# 3. Correlation Heatmap – Relationship Between Sensor Readings
# Strong Positive Correlations:
# Methane and CO (0.79): These gases often increase together in transformer failures.
# Ethylene and Ethane (0.79): Both gases are closely related to thermal decomposition in transformers.
# DBDS and CO2 (0.73): This suggests that Dibenzyl Disulfide (DBDS) degradation is related to CO2 formation, likely from paper insulation breakdown.
# Health Index and Life Expectation (0.71): As expected, transformers with higher health indices tend to have longer life expectancies.
# Negative Correlations:
# Health Index vs. Acetylene (-0.52): High Acetylene concentrations strongly indicate transformer degradation, leading to a lower Health Index.
# Health Index vs. Ethylene (-0.46): High Ethylene levels suggest overheating, which negatively impacts transformer health.
# Water Content vs. Dielectric Rigidity (-0.61): More water in the transformer oil significantly reduces its dielectric strength, increasing failure risk.
# Key Insights and Next Steps
# The Health Index is highly correlated with multiple gas levels, especially Acetylene and Ethylene, which indicates thermal degradation and arcing issues.
# Methane, CO, and CO2 are closely related and should be considered in predictive modeling.
# Outliers must be analyzed carefully—removing incorrect sensor readings vs. retaining extreme values for failure prediction.
# Feature selection for the Machine Learning model should prioritize highly correlated features such as:
# Acetylene, Ethylene, Methane, CO, CO2, Water Content, and DBDS.
# By incorporating these findings, we can build a predictive model to classify transformers into Healthy, Warning, and Critical conditions, helping with predictive maintenance and failure prevention.
